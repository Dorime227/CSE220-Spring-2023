# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorime227/CSE220-Spring-2023/blob/main/Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Patient:
  def __init__(self,id,name,age,bloodgroup,next,prev):
    self.id=id
    self.name=name
    self.age=age
    self.bloodgroup=bloodgroup
    self.next=next
    self.prev=prev
class WRM:
  def __init__(self):
      self.dummy=Patient(None,None,None,None,None,None)
      self.dummy.next=self.dummy
      self.dummy.prev=self.dummy
      self.tail=self.dummy

  def RegisterPatient(self,id,name,age,bloodgroup):
    print(f'\nSuccess\n\n{name} is Registered')
    new=Patient(id,name,age,bloodgroup,None,None)
    temp=self.dummy.prev
    self.dummy.prev=new
    temp.next=new
    new.next=self.dummy
    new.prev=temp

  def ServePatient(self):
    if self.dummy.next!=self.dummy:

      print(f'{self.dummy.next.name} is served ')
      self.dummy.next=self.dummy.next.next
    else:
      print('No patient left for serve')

  def CancelAll(self):
    self.dummy.next=self.dummy
    self.dummy.prev=self.dummy

  def CanDoctorGoHome(self):
    if self.dummy.next!=self.dummy:
      print('No. Patiens are still left.')
    else:
      print('Yes. The doctor can go home now.')

  def ShowAllPatient(self):
    temp=self.dummy
    k=1
    if temp.next==self.dummy:
      print('No patient left')
    else:
      while temp.next!=self.dummy:
        print(f'Name of the patient {k}: {temp.next.name}')
        k+=1
        temp=temp.next


func=WRM()
loop=0
while loop<2:
  print()
  print(f'**Welcome to Waiting Room Management System**')
  print()
  print(f'==Choose an Option==')
  print()
  print(f'1. Register Patient\n2. Serve Patient\n3. Cancel All\n4. Can Doctor Go Home?\n5. Show details of all patient\n6. exit\n=========================')
  user_input=int(input('Please enter your choice: '))
  if user_input==1:
    print('Starting the process...\n')
    id=input('\nPlease enter an ID: ')
    name=input('\nPlease enter a name: ')
    age=int(input('\nPlease enter the age: '))
    bloodgroup=input('\nPlease enter the Blood Group: ')
    func.RegisterPatient(id,name,age,bloodgroup)
  elif user_input==2:
    print()
    func.ServePatient()
  elif user_input==3:
    print()
    print('All appoinments are canceled')
    func.CancelAll()
  elif user_input==4:
    print()
    func.CanDoctorGoHome()
  elif user_input==5:
    print()
    func.ShowAllPatient()
  elif user_input==6:
    print()
    print('Thank You for using Waiting Room Management System\nEXITING...')
    break
  else:
    print()
    print('Please enter a valid option')
# Out:
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 101
#
# Please enter a name: Naruto
#
# Please enter the age: 25
#
# Please enter the Blood Group: B+
#
# Success
#
# Naruto is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 1
#
# Please enter a name: Kakashi Hatake
#
# Please enter the age: 43
#
# Please enter the Blood Group: A+
#
# Success
#
# Kakashi Hatake is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 103
#
# Please enter a name: Sasuke
#
# Please enter the age: 25
#
# Please enter the Blood Group: A+
#
# Success
#
# Sasuke is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 104
#
# Please enter a name: Light Yagami
#
# Please enter the age: 19
#
# Please enter the Blood Group: A+
#
# Success
#
# Light Yagami is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 105
#
# Please enter a name: Killer Bee
#
# Please enter the age: 29
#
# Please enter the Blood Group: B+
#
# Success
#
# Killer Bee is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 106
#
# Please enter a name: Maki
#
# Please enter the age: 21
#
# Please enter the Blood Group: A+
#
# Success
#
# Maki is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 1
# Starting the process...
#
#
# Please enter an ID: 107
#
# Please enter a name: Deidara
#
# Please enter the age: 21
#
# Please enter the Blood Group: A+
#
# Success
#
# Deidara is Registered
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Naruto
# Name of the patient 2: Kakashi Hatake
# Name of the patient 3: Sasuke
# Name of the patient 4: Light Yagami
# Name of the patient 5: Killer Bee
# Name of the patient 6: Maki
# Name of the patient 7: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Naruto is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Kakashi Hatake is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Sasuke
# Name of the patient 2: Light Yagami
# Name of the patient 3: Killer Bee
# Name of the patient 4: Maki
# Name of the patient 5: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Sasuke is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Light Yagami is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Killer Bee
# Name of the patient 2: Maki
# Name of the patient 3: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 4
#
# No. Patiens are still left.
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Killer Bee
# Name of the patient 2: Maki
# Name of the patient 3: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Killer Bee is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Maki
# Name of the patient 2: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# Maki is served
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# Name of the patient 1: Deidara
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 3
#
# All appoinments are canceled
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 2
#
# No patient left for serve
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 5
#
# No patient left
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 4
#
# Yes. The doctor can go home now.
#
# **Welcome to Waiting Room Management System**
#
# ==Choose an Option==
#
# 1. Register Patient
# 2. Serve Patient
# 3. Cancel All
# 4. Can Doctor Go Home?
# 5. Show details of all patient
# 6. exit
# =========================
# Please enter your choice: 6
#
# Thank You for using Waiting Room Management System
# EXITING...
